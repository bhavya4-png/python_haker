# %%
if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))

    arr = sorted(set(arr))

    if len(arr) >= 2:
        print(arr[-2])
    else:
        print("No runner-up score")
# Out:
# No runner-up score
